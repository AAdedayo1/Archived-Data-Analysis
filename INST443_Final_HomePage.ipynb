# %% [markdown]
# # Black Businesses and Employment in 1911 Charlotte, NC

# %% [markdown]
# * Authors: Adetomilola Adedayo & Jordan Goodman
# * Course: INST443 - Tools and Methods for Digital Curation
# * Professor: Richard Marciano
# * Date: May 9, 2024

# %% [markdown]
# ![Screenshot%202024-05-08%20at%208.06.05%20PM.png](attachment:Screenshot%202024-05-08%20at%208.06.05%20PM.png)

# %% [markdown]
# In this notebook we will explore and analyze subsections of The 1911 Charlotte, North Carolina City Directory. Through this exploration we hope to uncover facts and trends of black businesses and employment in 1911 Charlotte. We will be able to do this using:
#
# 1. Data Source: [Charlotte Directory from Internet Archives](https://dn790002.ca.archive.org/0/items/charlottenorthca1911pied/charlottenorthca1911pied.pdf)
# 2. Tools: ABBYY FineReader, OpenRefine, Tableau

# %% [markdown]
# ### Computational Thinking
#
# Data Practices
# * Collecting Data
# * Manipulating Data
# * Analyzing Data
# * Visualizing Data
#
# Modeling and Simulation Practices
# * Using Computational Models to Understand a Concept
#
# Computational Problem Solving Practices
# * Preparing Problems for Computational Solutions
# * Choosing Effective Computational Tools
# * Assessing Different Approaches/Solutions to a Problem
# * Troubleshooting and Debugging
#
# Systems Thinking Practices
# * Understanding the Relationships Within a System

# %% [markdown]
# ### Project Overview

# %% [markdown]
# This project is broken up into 3 parts including Data Collection, Data Cleaning and Manipulation, and Data Visualization. Each part is essential to accomplishing our goal of understanding more about Black businesses and employment in 1911 Charlotte, NC. We will discuss the ways in which we extracted data from the archived city directory, how we cleaned that data and prepared it for analysis.

# %% [markdown]
# ### Notebooks
#
# 1. [Introduction](http://localhost:8888/notebooks/Downloads/AAdedayo_JGoodman_INST443_Final/INST443_Final_HomePage.ipynb)
# 2. [Data Collection](http://localhost:8888/notebooks/Downloads/AAdedayo_JGoodman_INST443_Final/INST443_Final_DataCollection.ipynb)
# 3. [Data Cleaning and Manipulation](http://localhost:8888/notebooks/Downloads/AAdedayo_JGoodman_INST443_Final/INST443_Final_DataCleaning.ipynb)
# 4. [Data Visualization](http://localhost:8888/notebooks/Downloads/AAdedayo_JGoodman_INST443_Final/INST443_Final_DataVisualization.ipynb)
# 5. [Conclusion](http://localhost:8888/notebooks/Downloads/AAdedayo_JGoodman_INST443_Final/INST443_Final_Conclusion.ipynb)
#
#
# Next: [Data Collection](http://localhost:8888/notebooks/Downloads/AAdedayo_JGoodman_INST443_Final/INST443_Final_DataCollection.ipynb)
