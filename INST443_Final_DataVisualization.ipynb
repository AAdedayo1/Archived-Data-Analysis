# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Tableau

# %% [markdown]
# Our project is focused on black employment using the subsections of the Charlotte, NC Business Directory and City Directory. In the first and second parts of our project, ABBYY FineREader and OpenRefine were used to extract and manipulate data for cleaning. In part three, we created charts and graphs in Tableau for visual effect from our cleaned datasets. We also included data from the General Charlotte 1911 Directory dataset provided to us by Professor Marciano to examine the difference between the employment patterns of both white and black people. Using Tableau, we created visualizations to examine a number of different factors of the data in our created dataset, which includes only the Black businesses from the Business Directory. The four following sections explain the factors we explored from our dataset.

# %% [markdown]
# ### The Job Types of Black Residents
#
# ![Job%20Types%20Black%20Residents%20renewed.png](attachment:Job%20Types%20Black%20Residents%20renewed.png)
#
# Using both of our datasets extracted and manipulated from ABBYY and OpenRefine, I then used Tableau to visualize the Job Types of black people. I used the filtering within Tableau to exclude nulll entries from the 'Job Type' column (exclusion of null values was the chosen filter for each visualization for accuracy).

# %% [markdown]
# ### The Business Type (Categories) of Black Residents
#
# ![Categories%20of%20Black%20Businesses%20.png](attachment:Categories%20of%20Black%20Businesses%20.png)
#
# Using our Charlotte_Black_Business_Directory dataset, I then wanted to capture the Categories of Businesses from the black population using the 'Categories' data. In Tableau, I was able to show which entries are included in the 'categories' from the Business Directory.

# %% [markdown]
# ### The Businesses That Employed Black Residents
#
# ![Bar%20chart%20job,%20company,%20race%20breakdown.png](attachment:Bar%20chart%20job,%20company,%20race%20breakdown.png)
#
# Using our Charlotte_Black_Business_Directory dataset, I then wanted to capture the Categories of companies amongst the black population using the 'Job Type' data. In Tableau, I was able to make relations between both of our OpenRefine and ABBYY extracted Business Directroy to show which entries are included in the 'companies' from the Business Directory.

# %% [markdown]
# ### Job Type Comparison: White v Black
#
# ![White%20v%20Black%20Job%20Types%20Comparison.png](attachment:White%20v%20Black%20Job%20Types%20Comparison.png)
#
# Using the Charlotte 1911 Directory, I wanted to compare the job types of the white population with the black population. I decided to use the general directory because our project is focused on the black population; therefore, I decided to use this dataset as a sample size of the white population to compare any noticible patterns amongst job types. I filtered the graph by excluding null values in both the 'race' and 'job-type' columns for accuracy. I also used the count measure in the directory to observe the job-types that were either common or uncommon in both demographics.

# %% [markdown]
# ### Key Findings: Using Tableau Public

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1715228684356' style='position: relative'><noscript><a href='#'><img alt='Employment Types of  Black Residents in Charlotte, NC 1911 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bl&#47;Black-OwnedBusinessesin1911CharlotteNC&#47;BusinessTypes&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Black-OwnedBusinessesin1911CharlotteNC&#47;BusinessTypes' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bl&#47;Black-OwnedBusinessesin1911CharlotteNC&#47;BusinessTypes&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1715228684356');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1715228684356' style='position: relative'><noscript><a href='#'><img alt='Employment Types of  Black Residents in Charlotte, NC 1911 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bl&#47;Black-OwnedBusinessesin1911CharlotteNC&#47;BusinessTypes&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Black-OwnedBusinessesin1911CharlotteNC&#47;BusinessTypes' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bl&#47;Black-OwnedBusinessesin1911CharlotteNC&#47;BusinessTypes&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='disp
# ...

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1715229031610' style='position: relative'><noscript><a href='#'><img alt='Job Types of Black Residents in Charlotte, NC 1911 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bl&#47;Black-JobTypesin1911CharlotteNC&#47;JobTypes&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Black-JobTypesin1911CharlotteNC&#47;JobTypes' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bl&#47;Black-JobTypesin1911CharlotteNC&#47;JobTypes&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1715229031610');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1715229031610' style='position: relative'><noscript><a href='#'><img alt='Job Types of Black Residents in Charlotte, NC 1911 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bl&#47;Black-JobTypesin1911CharlotteNC&#47;JobTypes&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Black-JobTypesin1911CharlotteNC&#47;JobTypes' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bl&#47;Black-JobTypesin1911CharlotteNC&#47;JobTypes&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='disp
# ...

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1715229173412' style='position: relative'><noscript><a href='#'><img alt='Charlotte 1911 Businesses by Job, Company, and Race ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bl&#47;Black-JobsbyCompanyin1911CharlotteNC&#47;BusinessesbyJobCompanyandRace&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Black-JobsbyCompanyin1911CharlotteNC&#47;BusinessesbyJobCompanyandRace' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bl&#47;Black-JobsbyCompanyin1911CharlotteNC&#47;BusinessesbyJobCompanyandRace&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1715229173412');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1715229173412' style='position: relative'><noscript><a href='#'><img alt='Charlotte 1911 Businesses by Job, Company, and Race ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bl&#47;Black-JobsbyCompanyin1911CharlotteNC&#47;BusinessesbyJobCompanyandRace&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Black-JobsbyCompanyin1911CharlotteNC&#47;BusinessesbyJobCompanyandRace' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Bl&#47;Black-JobsbyCompanyin1911CharlotteNC&#47;BusinessesbyJobCompanyandRace&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_ima
# ...

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1715229273571' style='position: relative'><noscript><a href='#'><img alt='Charlotte, NC 1911 Job Types By Race ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;19&#47;1911CharlotteNCJob-TypesBlackvWhite&#47;CharlotteNC1911JobTypesByRace&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='1911CharlotteNCJob-TypesBlackvWhite&#47;CharlotteNC1911JobTypesByRace' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;19&#47;1911CharlotteNCJob-TypesBlackvWhite&#47;CharlotteNC1911JobTypesByRace&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1715229273571');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1715229273571' style='position: relative'><noscript><a href='#'><img alt='Charlotte, NC 1911 Job Types By Race ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;19&#47;1911CharlotteNCJob-TypesBlackvWhite&#47;CharlotteNC1911JobTypesByRace&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='1911CharlotteNCJob-TypesBlackvWhite&#47;CharlotteNC1911JobTypesByRace' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;19&#47;1911CharlotteNCJob-TypesBlackvWhite&#47;CharlotteNC1911JobTypesByRace&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' />
# ...

# %% [markdown]
# ### Notebooks
#
#
# 1. [Introduction](http://localhost:8888/notebooks/Downloads/AAdedayo_JGoodman_INST443_Final/INST443_Final_HomePage.ipynb)
# 2. [Data Collection](http://localhost:8888/notebooks/Downloads/AAdedayo_JGoodman_INST443_Final/INST443_Final_DataCollection.ipynb)
# 3. [Data Cleaning and Manipulation](http://localhost:8888/notebooks/Downloads/AAdedayo_JGoodman_INST443_Final/INST443_Final_DataCleaning.ipynb)
# 4. [Data Visualization](http://localhost:8888/notebooks/Downloads/AAdedayo_JGoodman_INST443_Final/INST443_Final_DataVisualization.ipynb)
# 5. [Conclusion](http://localhost:8888/notebooks/Downloads/AAdedayo_JGoodman_INST443_Final/INST443_Final_Conclusion.ipynb)
#
# Next: [Conclusion](http://localhost:8888/notebooks/Downloads/AAdedayo_JGoodman_INST443_Final/INST443_Final_Conclusion.ipynb)
